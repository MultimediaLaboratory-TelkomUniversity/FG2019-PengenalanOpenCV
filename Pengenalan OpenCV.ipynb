# %% [markdown]
# <img src='multimedia.png' width=100px align='left'>

# %% [markdown]
# ## Pengenalan OpenCV dan Pengolahan Citra Digital Part 1

# %% [markdown]
# Halo! Kali ini kita akan belajar tentang cara menggunakan openCV.
# Jadi, di python itu ada beberapa package untuk melakukan pengolahan citra digital. Packagenya adalah sebagai berikut
# 1. Skimage
# 2. PIL
# 3. OpenCV (Yang akan dipelajari pada FG Programming)
#
# What are you waiting for? Let's Have Fun

# %% [markdown]
# ### Import Package

# %% [markdown]
# Lakukan import package terlebih dahulu

# %%
#lakukan import package opencv
import cv2

#matplotlib fungsinya untuk menampilkan gambar atau grafik
import matplotlib.pyplot as plt

# %% [markdown]
# ### Let's Start!

# %% [markdown]
# Setelah itu marilah kita read satu gambar, cari gambar kemudian masukkan di folder yang sama dengan tempat kamu buat notebook ini

# %%
#read gambar
img = cv2.imread('pokemon.jpg')

# %%
#menampilkan informasi pada gambar
print('Dimensi Gambar: ',img.shape)
# Out:
# Dimensi Gambar:  (600, 800, 3)

# %%
#tampilkan gambar
cv2.imshow('inigambar',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Operasi Dasar Citra (Review Materi Pertemuan 1)

# %% [markdown]
# #### Operasi Warna

# %%
#ubah gambar dari RGB ke Grayscale 
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('gray',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#ubah gambar dari RGB ke HSV
hsv_image = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

cv2.imshow('gray',hsv_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Inverse
inverse_img = 255-img

cv2.imshow('gray',inverse_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Grayscale to Binary menggunakan threshold (bila lebih besar dari threshold maka nilainya 1 
#kalau lebih kecil maka nilainya 0)

#keterangan lib, yang 125 merupakan thresholdnya, bisa diganti sesuka hati asal jangan melebihi 255.
ret, thresh = cv2.threshold(gray_img,125,255,cv2.THRESH_BINARY)
cv2.imshow('gray',thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Histogram

# %%
#menampilkan gambar dalam notebook. Sebelum menampilkan gambar, gambar dikonvert dulu dari BGR ke RGB 
#karena OpenCV membaca gambar bukan dalam bentuk RGB, melainkan BGR.
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
#buat histogram dari gambar
hist = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist)

#plot histogram untuk masing-masing channel
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color= col)
    plt.show()

# %% [markdown]
# ### Operasi Dasar Citra Terbaru

# %% [markdown]
# #### Mengubah Ukuran Citra (Resize)

# %%
# memperbesar atau memperkecil ukuran citra
width = int(img.shape[1]*0.5)
height = int(img.shape[0]*0.5)
dim = (width,height)

resized = cv2.resize(img,dim)
cv2.imshow("Resized image", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Flip Gambar

# %%
horizontal_img = cv2.flip(img,0)
vertical_img = cv2.flip(img,1)
cv2.imshow("Flip Vertical", vertical_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Rotate Gambar

# %%
#Memutar Gambar

#menentukan letak poros, jadi letak porosnya berada di setengah tinggi dan setengah lebar.
h,w = img.shape[:2]
center = (w/2,h/2)

#sebelum melakukan perputaran, tentukan poros, sudut, dan arahnya.
rotate = cv2.getRotationMatrix2D(center,45,1)
rotatingImg = cv2.warpAffine(img,rotate,(w,h))
cv2.imshow("Rotate 45",rotatingImg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Konvolusi

# %% [markdown]
# #### Excercise (Dikerjakan di lab)

# %% [markdown]
# coba-coba konvolusi dengan kernel untuk edge, blur, sharp

# %%
# Exercise, coba-coba konvolusi edge blur sharp
# Penjelasan akan dijelaskan di pertemuan selanjutnya
